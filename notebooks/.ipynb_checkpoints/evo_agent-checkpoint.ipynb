# %%
import sys
sys.path.insert(1, 'C://Users//arthu//git//eyenes')
from eyenes.generation import Generation
import pickle
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
dicto = {'size': 20, 'max_steps': 3000, 'freq': .25, 'buffer': 3,
        'layer_prob': .25, 'intensity': 1, 'fps': 4, 'patience': 3,
        'num_survivors': 4, 'similar_penalty': .9, 'mode': 'sequential'}

# %%
def save_all(generation):
    pickle.dump(generation.history, open('history.pkl','wb'))
    for i, agent in enumerate(generation.agents):
        pickle.dump(agent.model.model.get_weights(), open('weight_' + str(i) + '.pkl', 'wb'))
        pickle.dump(agent.lineage, open('lineage_' + str(i) + '.pkl', 'wb'))
        
def load_all(generation):
    generation.history = pickle.load(open('history.pkl','rb'))
    for i, agent in enumerate(generation.agents):
        agent.model.model.set_weights(pickle.load(open('weight_' + str(i) + '.pkl', 'rb')))
        agent.lineage = pickle.load(open('lineage_' + str(i) + '.pkl', 'rb'))

# %%
generation = Generation(**dicto)
load_all(generation)

# %%
for i in range(1000):
    generation.evolution_step(plot = True)
    save_all(generation)

# %%
def safe_reward(agent):
    if agent.total_reward is not None:
        return agent.total_reward
    else:
        return -1
    
rewards = [safe_reward(agent) for agent in generation.agents if agent.total_reward]
generation.agents[np.argmax(rewards)].max_steps = 999999
generation.agents[np.argmax(rewards)].run(mode = 'render')
